# %%
d={"key": "value", "key1": "value1"}

# %%
d['key']
# Out:
# 'value'

# %%
d.key
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 d.key
#
# AttributeError: 'dict' object has no attribute 'key'

# %%
from box import ConfigBox

# %%
d2= ConfigBox({"key": "value", "key1": "value1"})

# %%
d2
# Out:
# ConfigBox({'key': 'value', 'key1': 'value1'})

# %%
d2.key
# Out:
# 'value'

# %%
def get_product(x: int, y: int) -> int:
    return x*y

# %%
get_product(x=2,y=4)
# Out:
# 8

# %%
get_product(2,"4")
# Out:
# '44'

# %%
from typeguard import typechecked
# from ensure import ensure_annotations


# @ensure_annotations
@typechecked
def get_product(x: int, y: int) -> int:
    return x * y

# %%
get_product(x=2,y="4")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 get_product(x=2,y="4")
#
# File c:\Users\chauh\miniconda3\envs\codexenv\Lib\site-packages\typeguard\__init__.py:1032, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1030 def wrapper(*args, **kwargs):
#    1031     memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
# -> 1032     check_argument_types(memo)
#    1033     retval = func(*args, **kwargs)
#    1034     try:
#
# File c:\Users\chauh\miniconda3\envs\codexenv\Lib\site-packages\typeguard\__init__.py:875, in check_argument_types(memo)
#     873             check_type(description, value, expected_type, memo)
#     874         except TypeError as exc:  # suppress unnecessarily long tracebacks
# --> 875             raise TypeError(*exc.args) from None
#     877 return True
#
# TypeError: type of argument "y" must be int; got str instead
